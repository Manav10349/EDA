# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cars.csv')

# %%
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
# 5          2                 ?         audi       gas        sedan
# 6          1               158         audi       gas        sedan
# 7          1                 ?         audi       gas        wagon
# 8          1               158         audi       gas        sedan
# 9          0                 ?         audi       gas    hatchback
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
# 5          fwd           front   66.3    53.1         ohc          136
# 6          fwd           front   71.4    55.7         ohc          136
# 7          fwd           front   71.4    55.7         ohc          136
# 8          fwd           front   71.4    55.9         ohc          131
# 9          4wd           front   67.9    52.0         ohc          131
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# 2        154        19           26  16500
# 3        102        24           30  13950
# 4        115        18           22  17450
# 5        110        19           25  15250
# 6        110        19           25  17710
# 7        110        19           25  18920
# 8        140        17           20  23875
# 9        160        16           22  12000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.2+ KB

# %% [markdown]
# # freature and target should be seperated

# %% [markdown]
# # feature and targets should be numberic

# %% [markdown]
# # both must be in same dimensions and in proper shape

# %%
#seperate feature & target

features=df.iloc[:,:-1]
target=df.iloc[:,-1]

# %%
features.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg
# 0        111        21           27
# 1        111        21           27
# 2        154        19           26
# 3        102        24           30
# 4        115        18           22

# %%
target.head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df['horsepower'].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64

# %%
features.replace('?',np.nan,inplace=True)
target.replace('?',np.nan,inplace=True)

# %%
features.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3               NaN  alfa-romero       gas  convertible
# 1          3               NaN  alfa-romero       gas  convertible
# 2          1               NaN  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg
# 0        111        21           27
# 1        111        21           27
# 2        154        19           26
# 3        102        24           30
# 4        115        18           22

# %%
target.head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()

# %%
#re assigning value to both columns
features[['normalized-losses','horsepower']]=si.fit_transform(features[['normalized-losses','horsepower']])

# %%
features.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg
# 0       111.0        21           27
# 1       111.0        21           27
# 2       154.0        19           26
# 3       102.0        24           30
# 4       115.0        18           22

# %% [markdown]
# # Outlier removal

# %%
sns.boxplot(data=features,x=target)
plt.show()

# %%
sns.boxplot(data=features,x=target,y='make')
plt.grid()
plt.show()

# %%
i=features[(features.make=='dodge')&(target>10000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

i=features[(features.make=='honda')&(target>12000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

i=features[(features.make=='isuzu')&(target>20000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

i=features[(features.make=='mitsubishi')&(target>13000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

i=features[(features.make=='plymouth')&(target>12000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

i=features[(features.make=='toyota')&(target>15000)].index
features.drop(i,axis=0,inplace=True)
target.drop(i,axis=0,inplace=True)

# %%
sns.boxplot(data=features,x=target,y='make')
plt.grid()
plt.show()

# %%
# if the column which has skewness showing good relation with target do not remove
# if the column which as negetive value do not remove skewness

# %% [markdown]
# # Skewness removal

# %%
cat_col=features.select_dtypes(['int','float'])
cat_col.head()
# Out:
#    symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0          3              122.0   64.1    48.8          130       111.0
# 1          3              122.0   64.1    48.8          130       111.0
# 2          1              122.0   65.5    52.4          152       154.0
# 3          2              164.0   66.2    54.3          109       102.0
# 4          2              164.0   66.4    54.3          136       115.0
#
#    city-mpg  highway-mpg
# 0        21           27
# 1        21           27
# 2        19           26
# 3        24           30
# 4        18           22

# %%
from scipy.stats import skew

skew(features['normalized-losses'])
# Out:
# 0.848205953606264

# %%
for i in cat_col:
    print(i)
    print(skew(features[i]))
    
    plt.figure()
    sns.distplot(features[i])
    plt.show()
# Out:
# symboling
# 0.21386866184357742
# normalized-losses
# 0.848205953606264
# width
# 0.9140400320504322
# height
# 0.013839962443639326
# engine-size
# 2.0541257626466156
# horsepower
# 1.5556576549504106
# city-mpg
# 0.5999073033714895
# highway-mpg
# 0.4760310091695327

# %%
np.sqrt(900)
# Out:
# 30.0

# %%
pd.concat([features,target],axis=1).corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_86070_row0_col0, #T_86070_row1_col1, #T_86070_row2_col2, #T_86070_row3_col3, #T_86070_row4_col4, #T_86070_row5_col5, #T_86070_row6_col6, #T_86070_row7_col7, #T_86070_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_86070_row0_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_86070_row0_col2, #T_86070_row4_col0 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_86070_row0_col3, #T_86070_row3_col0, #T_86070_row3_col1, #T_86070_row5_col6, #T_86070_row5_col7, #T_86070_row6_col5, #T_86070_row7_col2, #T_86070_row7_col4, #T_86070_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_86070_row0_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_86070_row0_col5, #T_86070_row3_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_86070_row0_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_86070_row0_col7 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_86070_row0_col8 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_86070_row1_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_86070_row1_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_86070_row1_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_86070_row1_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_86070_row1_col5 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_86070_row1_col6 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_86070_row1_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_86070_row1_col8 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_86070_row2_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_86070_row2_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_86070_row2_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_86070_row2_col4, #T_86070_row2_col8, #T_86070_row4_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_86070_row2_col5 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_86070_row2_col6, #T_86070_row4_col6 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_86070_row2_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_86070_row3_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_86070_row3_col5, #T_86070_row3_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_86070_row3_col7 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_86070_row3_col8 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_86070_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_86070_row4_col3, #T_86070_row5_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_86070_row4_col5 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_86070_row4_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_86070_row4_col8 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_86070_row5_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_86070_row5_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_86070_row5_col3, #T_86070_row6_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_86070_row5_col4 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_86070_row5_col8 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_86070_row6_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_86070_row6_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_86070_row6_col2, #T_86070_row7_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_86070_row6_col4, #T_86070_row6_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_86070_row6_col7, #T_86070_row7_col6 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_86070_row7_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_86070_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_86070_row7_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_86070_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_86070_row8_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_86070_row8_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_86070_row8_col3 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_86070_row8_col4 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_86070_row8_col5 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_86070_row8_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_86070_row8_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_86070">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86070_level0_col0" class="col_heading level0 col0" >symboling</th>
#       <th id="T_86070_level0_col1" class="col_heading level0 col1" >normalized-losses</th>
#       <th id="T_86070_level0_col2" class="col_heading level0 col2" >width</th>
#       <th id="T_86070_level0_col3" class="col_heading level0 col3" >height</th>
#       <th id="T_86070_level0_col4" class="col_heading level0 col4" >engine-size</th>
#       <th id="T_86070_level0_col5" class="col_heading level0 col5" >horsepower</th>
#       <th id="T_86070_level0_col6" class="col_heading level0 col6" >city-mpg</th>
#       <th id="T_86070_level0_col7" class="col_heading level0 col7" >highway-mpg</th>
#       <th id="T_86070_level0_col8" class="col_heading level0 col8" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86070_level0_row0" class="row_heading level0 row0" >symboling</th>
#       <td id="T_86070_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_86070_row0_col1" class="data row0 col1" >0.447922</td>
#       <td id="T_86070_row0_col2" class="data row0 col2" >-0.272388</td>
#       <td id="T_86070_row0_col3" class="data row0 col3" >-0.521495</td>
#       <td id="T_86070_row0_col4" class="data row0 col4" >-0.153671</td>
#       <td id="T_86070_row0_col5" class="data row0 col5" >0.027074</td>
#       <td id="T_86070_row0_col6" class="data row0 col6" >0.007189</td>
#       <td id="T_86070_row0_col7" class="data row0 col7" >0.084238</td>
#       <td id="T_86070_row0_col8" class="data row0 col8" >-0.095905</td>
#     </tr>
#     <tr>
#       <th id="T_86070_level0_row1" class="row_heading level0 row1" >normalized-losses</th>
#       <td id="T_86070_row1_col0" class="data row1 col0" >0.447922</td>
#       <td id="T_86070_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_86070_row1_col2" class="data row1 col2" >0.066622</td>
#       <td id="T_86070_row1_col3" class="data row1 col3" >-0.368540</td>
#       <td id="T_86070_row1_col4" class="data row1 col4" >0.090258</td>
#       <td id="T_86070_row1_col5" class="data row1 col5" >0.183385</td>
#       <td id="T_86070_row1_col6" class="data row1 col6" >-0.212276</td>
#       <td id="T_86070_row1_col7" class="data row1 col7" >-0.168904</td>
#       <td id="T_86070_row1_col8" class="data row1 col8" >0.129973</td>
#     </tr>
#     <tr>
#       <th id="T_86070_level0_row2" class="row_heading level0 row2" >width</th>
#       <td id="T_86070_row2_col0" class="data row2 col0" >-0.272388</td>
#       <td id="T_86070_row2_col1" class="data row2 col1" >0.066622</td>
#       <td id="T_86070_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_86070_row2_col3" class="data row2 col3" >0.296011</td>
#       <td id="T_86070_row2_col4" class="data row2 col4" >0.735112</td>
#       <td id="T_86070_row2_col5" class="data row2 col5" >0.643906</td>
#       <td id="T_86070_row2_col6" class="data row2 col6" >-0.641401</td>
#       <td id="T_86070_row2_col7" class="data row2 col7" >-0.677911</td>
#       <td id="T_86070_row2_col8" class="data row2 col8" >0.730503</td>
#     </tr>
#     <tr>
#       <th id="T_86070_level0_row3" class="row_heading level0 row3" >height</th>
#       <td id="T_86070_row3_col0" class="data row3 col0" >-0.521495</td>
#       <td id="T_86070_row3_col1" class="data row3 col1" >-0.368540</td>
#       <td id="T_86070_row3_col2" class="data row3 col2" >0.296011</td>
#       <td id="T_86070_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_86070_row3_col4" class="data row3 col4" >0.096041</td>
#       <td id="T_86070_row3_col5" class="data row3 col5" >-0.078245</td>
#       <td id="T_86070_row3_co

# %%
skew(features['normalized-losses'])
# Out:
# 0.848205953606264

# %%
features['normalized-losses']=np.log(features['normalized-losses'])

# %%
skew(features['normalized-losses'])
# Out:
# 0.018468899462087518

# %% [markdown]
# HENCE, All Outlier are remove and skewness is handle now the data is cleaned and organised
